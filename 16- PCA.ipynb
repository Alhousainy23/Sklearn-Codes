# %%
#First Example 
import numpy as np
from sklearn.decomposition import PCA
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
print('**'*20)
pca = PCA(n_components=2, svd_solver='full')
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
print('**'*20)
pca = PCA(n_components=1, svd_solver='arpack')
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
print('**'*20)
# Out:
# [0.99244289 0.00755711]
# [6.30061232 0.54980396]
# ****************************************
# [0.99244289 0.00755711]
# [6.30061232 0.54980396]
# ****************************************
# [0.99244289]
# [6.30061232]
# ****************************************

# %%
#Another Example For Iris Data 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets
np.random.seed(5)
centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1])
plt.cla()

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)
for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() ,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float32)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,edgecolor='k')
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
plt.show()
# Out:
# C:\Users\Alhou\AppData\Local\Temp\ipykernel_15644\1552459660.py:13: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# C:\Users\Alhou\AppData\Local\Temp\ipykernel_15644\1552459660.py:14: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# C:\Users\Alhou\AppData\Local\Temp\ipykernel_15644\1552459660.py:15: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])

# %%
#Another Example For PCA 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
rn = np.random.RandomState()
x = np.dot(rn.rand(2,2) , rn.randn(2,100) ).T
x.shape
model = PCA(n_components= 1)
model.fit(x)
data = model.transform(x)
x.shape
data.shape
newdata = model.inverse_transform(data)
plt.scatter(x[:,0],x[:,1])
plt.scatter(newdata[:,0],newdata[:,1])
