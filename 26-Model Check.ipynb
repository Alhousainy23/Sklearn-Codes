# %% [markdown]
# ## 1- Boston Houses Data

# %%
import pandas as pd
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import cross_validate
dataset = pd.read_csv('D:\\Programming\\Machine Learning Projects\\My Projects\\Data\\Boston.csv')
print(dataset.head())
print('***'*30)
x_data = dataset.iloc[:,:-1]
y_target = dataset.iloc[:,-1] 
print(x_data.shape)
#print(x_data[:5])
print('***'*30)
print(y_target.shape)
#print(y_target[:5])
print('***'*30)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# ******************************************************************************************
# (506, 14)
# ******************************************************************************************
# (506,)
# ******************************************************************************************

# %%
#Applying SGDRegressor Model 
SGDRegressionModel = SGDRegressor(alpha=0.1,random_state=33,penalty='l2',loss = 'huber')
#----------------------------------------------------
#Applying Cross Validate :  
'''
model_selection.cross_validate(estimator, X, y=None, groups=None, scoring=None, cv=’warn’, n_jobs=None,
verbose=0,fit_params=None, pre_dispatch=‘2*n_jobs’, return_train_score=’warn’,return_estimator=False,error_score=’raise-deprecating’)'''
#  don't forget to define the model first !!!
CrossValidateValues1 = cross_validate(SGDRegressionModel,x_data,y_target,cv=3,return_train_score = True)
CrossValidateValues2 = cross_validate(SGDRegressionModel,x_data,y_target,cv=3,scoring=('r2','neg_mean_squared_error'))
# Showing Results
print('Train Score Value : ', CrossValidateValues1['train_score'])
print('Test Score Value : ', CrossValidateValues1['test_score'])
print('Fit Time : ', CrossValidateValues1['fit_time'])
print('Score Time : ', CrossValidateValues1['score_time'])
#print('Train MSE Value : ', CrossValidateValues2['train_neg_mean_squared_error'])
#print('Test MSE Value : ', CrossValidateValues2['test_neg_mean_squared_error'])
#print('Train R2 Value : ', CrossValidateValues2['train_r2'])
#print('Test R2 Value : ', CrossValidateValues2['test_r2'])
# Out:
# Train Score Value :  [-0.45456165 -5.79131119 -8.06509139]
# Test Score Value :  [ -6.63688949  -0.35195999 -14.98323888]
# Fit Time :  [0.00212955 0.00797176 0.00800061]
# Score Time :  [0.         0.         0.00799966]

# %% [markdown]
# ## 2 - Another Example

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_validate
diabetes = datasets.load_diabetes()
X = diabetes.data[:150]
y = diabetes.target[:150]
reg= linear_model.LinearRegression()
cv_results = cross_validate(reg, X, y, cv=3,return_train_score=False)
for key in cv_results.keys():
    print('value of ' , key , ' is  ' , cv_results[key])
scores = cross_validate(reg, X, y, cv=5,scoring=('r2', 'neg_mean_squared_error'),return_train_score=True)
print('details are  : \n' , scores)
# Out:
# value of  fit_time  is   [0. 0. 0.]
# value of  score_time  is   [0. 0. 0.]
# value of  test_score  is   [0.49842308 0.10377707 0.44394205]
# details are  :
#  {'fit_time': array([0., 0., 0., 0., 0.]), 'score_time': array([0.        , 0.00799537, 0.        , 0.        , 0.        ]), 'test_r2': array([0.36323514, 0.28239373, 0.42116876, 0.3007132 , 0.61240106]), 'train_r2': array([0.54476081, 0.56725378, 0.52199455, 0.57510388, 0.4815239 ]), 'test_neg_mean_squared_error': array([-2547.3452611 , -4523.24854005, -2301.52884254, -4378.07068948,
#        -2409.22025436]), 'train_neg_mean_squared_error': array([-2763.25099256, -2366.59480814, -2820.72133794, -2314.73385014,
#        -2761.84411279])}

# %% [markdown]
# ## 3- Another Example

# %%
from sklearn import datasets

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict
diabetes = datasets.load_diabetes()
X = diabetes.data[:150]
y = diabetes.target[:150]
model1 = LinearRegression()
model2 = SVR(gamma = 'auto')
model3 = DecisionTreeRegressor()
model4 = RandomForestRegressor(n_estimators = 20)
models = [model1 , model2 , model3 , model4]
x=0
for m in models:
    x+=1
    for n in range(2,5):
        print('result of model number : ' , x ,' for cv value ',n,' is \n' , cross_val_predict(m, X, y, cv=n))  
        print('-----------------------------------')
    print('=====================================')
    print('=====================================')
# Out:
# result of model number :  1  for cv value  2  is
#  [186.91792246  40.90665079 135.60694123 200.15635871 126.36420499
#  124.836156    91.96388846  96.04075134 148.89330159 261.29402195
#  170.66829283  72.59909517 107.63466699 146.75323663  59.99305392
#  145.57422969 207.41862712 164.00136168 171.50503387 127.93383996
#  160.05247534 107.85668021 163.70992433 324.4911782  169.17350199
#  153.04293547 145.02707596 199.77373126 133.21536791 170.6087335
#  187.17536802  81.92659692 195.9370349   61.17605519  84.11045916
#   19.33601092 214.1294084  160.29801771 231.19815998 134.38128964
#  169.56163114 105.97374967 149.79342574  77.87686234 177.43735071
#   98.74159477 154.22578996 142.67098246  48.87413529 173.57533767
#  174.60324935 136.6149451  150.10109003 174.4657562  161.56784721
#   67.02536302 231.03945801  75.64376073   9.44257224 114.23532457
#  131.96049764 164.75209848  44.04399371 129.46631581  92.88656013
#  176.9513441  128.75639605 109.04713934  86.98877306 151.66102246
#   80.88135489 272.2585015  129.84917907  95.86644411 154.62314691
#  107.64778111 162.25316728  49.27852043 207.44632887  70.02643555
#  192.08006711 110.63005674  77.47686876 149.39192071  74.53561271
#  164.56315907  10.48422848 191.73213089  46.29013284 103.81798001
#   71.3962573  182.89554349 203.44308829  69.91970804 121.86171325
#  116.30218603 216.95868278 172.8030124  123.46827364 160.2776087
#  175.79990833  93.96662894 133.20729061 139.61477737 142.20285251
#  102.63476996  74.46326605 129.2163107  222.74644556  96.12076985
#    9.37610147 131.56471781 126.81121542 185.7222464  321.90332457
#  208.8317487  203.40921445 241.08185539 132.86473999 166.14447192
#  144.68199573 204.19192629 194.66607508 135.62235058 168.55233376
#  208.49822385  47.59764469 132.79114179 100.66929436 191.17959965
#  207.95802523  68.14241894  86.47237245  52.22379821 136.4057043
#  233.19801331  50.71147059 243.22263922 229.91523651 272.45506486
#  126.59082511 201.37099028 170.79953955 119.70512017 158.20394876
#  231.2852611  163.41460063 202.71490678  80.51362214 195.63347859]
# -----------------------------------
# -----------------------------------
# result of model number :  4  for cv value  4  is
#  [223.5   90.35 168.15 149.75  88.3   91.55 101.6  106.6  179.65 150.
#  123.8  144.8   83.05 180.7   83.7  188.1  219.8  203.4  128.35  75.
#  128.15 130.85 115.4  270.5  144.   134.4   96.4  172.6  127.4  204.3
#  132.45  71.85 222.6  118.15 105.75 139.65 217.8  109.6  212.85 171.2
#  180.2  148.35 149.55  99.65 181.1  126.5  133.2  114.25 125.05 179.45
#  107.15 171.8  106.7  105.25 115.95 107.55 208.65  80.45 137.25 165.9
#   90.35 168.9   73.55  91.85  82.25 215.65 138.95 100.3   77.5   97.5
#  118.95 252.75 187.9  142.75 174.5  135.1  152.9   81.6  188.7   97.15
#  195.7  118.15  96.   121.1   66.45 128.3   98.35 181.15  92.85 112.65
#   78.9  169.6  158.    99.4   96.6  141.45 220.7  143.8  144.2  116.45
#  191.25  80.5  147.65 120.65 124.45 117.1  119.8  110.35 234.95 101.95
#   76.4   89.4  117.8  175.45 259.   203.65 210.55 198.05 166.3  213.45
#  113.55 156.6  236.1  209.05 169.9  258.7   86.05  87.6  117.1  182.6
#  248.85  93.4   92.1   84.4  149.85 209.85  84.3  218.1  261.35 236.95
#  135.25 205.   163.55  82.85 177.05 180.7  182.85 241.95 130.3  211.2 ]
# -----------------------------------
# =====================================
# =====================================

# %% [markdown]
# ## 4- Another Example

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
dataset = pd.read_csv('D:\\Programming\\Machine Learning Projects\\My Projects\\Data\\Boston.csv')
print(dataset.head())
print('***'*30)
x_data = dataset.iloc[:,:-1]
y_target = dataset.iloc[:,-1] 
print(x_data.shape)
#print(x_data[:5])
print('***'*30)
print(y_target.shape)
#print(y_target[:5])
print('***'*30)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# ******************************************************************************************
# (506, 14)
# ******************************************************************************************
# (506,)
# ******************************************************************************************

# %%
#----------------------------------------------------
#Splitting data
X_train, X_test, y_train, y_test = train_test_split(x_data, y_target, test_size=0.33, random_state=44, shuffle =True)
#----------------------------------------------------
#Applying Ridge Regression Model 
RidgeRegressionModel = Ridge(alpha=1.0,random_state=33)
#----------------------------------------------------
#Applying Cross Validate Predict :  
'''model_selection.cross_val_predict(estimator, X, y=None, groups=None,cv=’warn’, n_jobs=None,verbose=0,fit_params=None, pre_dispatch=‘2*n_jobs’,method=’predict’)'''
#  don't forget to define the model first !!!
CrossValidatePredictionTrain = cross_val_predict(RidgeRegressionModel, X_train, y_train, cv=3)
CrossValidatePredictionTest = cross_val_predict(RidgeRegressionModel, X_test, y_test, cv=3)
# Showing Results
print('Cross Validate Prediction for Training Set: \n', CrossValidatePredictionTrain[:10])
print('Cross Validate Prediction for Testing Set: \n', CrossValidatePredictionTest[:10])
# Out:
# Cross Validate Prediction for Training Set:
#  [18.56986764 26.54612942 20.4777941  21.16937443 17.25030508 17.10255623
#  18.66233893 25.2611239  27.98179455 23.42158108]
# Cross Validate Prediction for Testing Set:
#  [13.63376206 26.1588875  24.20210392 41.21809466 15.85686104 36.73607514
#  21.97711702 23.8724869  29.08565992 29.16588283]

# %% [markdown]
# ## 5- Another Example

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
diabetes = datasets.load_diabetes()
X = diabetes.data[:150]
y = diabetes.target[:150]
model1 = LinearRegression()
model2 = SVR(gamma = 'auto')
model3 = DecisionTreeRegressor()
model4 = RandomForestRegressor(n_estimators = 100)
models = [model1 , model2 , model3 , model4]
x=0
for m in models:
    x+=1
    for n in range(2,11):
        print('result of model number : ' , x ,' for cv value ',n,' is ' , cross_val_score(m, X, y, cv=n))  
        print('-----------------------------------')
    print('=====================================')
    print('=====================================')
# Out:
# result of model number :  1  for cv value  2  is  [0.22893401 0.39992075]
# -----------------------------------
# result of model number :  1  for cv value  3  is  [0.49842308 0.10377707 0.44394205]
# -----------------------------------
# result of model number :  1  for cv value  4  is  [0.46946296 0.16765685 0.06191376 0.51579217]
# -----------------------------------
# result of model number :  1  for cv value  5  is  [0.36323514 0.28239373 0.42116876 0.3007132  0.61240106]
# -----------------------------------
# result of model number :  1  for cv value  6  is  [0.42057693 0.54445764 0.04701381 0.11830241 0.32818835 0.63724035]
# -----------------------------------
# result of model number :  1  for cv value  7  is  [ 0.48599755  0.49349863 -0.00359515  0.46673072 -0.00585454  0.46930577
#   0.61418895]
# -----------------------------------
# result of model number :  1  for cv value  8  is  [0.49344745 0.42252968 0.09380143 0.3971927  0.04406679 0.23262654
#  0.47735539 0.65522411]
# -----------------------------------
# result of model number :  1  for cv value  9  is  [ 0.5435087   0.35872554  0.5843291  -0.42825323  0.42755443 -0.06110799
#   0.32254773  0.47776829  0.61067389]
# -----------------------------------
# result of model number :  1  for cv value  10  is  [ 0.58662102  0.09908599  0.60312818 -0.42427993  0.53150952  0.40509414
#  -0.12272522  0.48435784  0.48719407  0.60278155]
# -----------------------------------
# =====================================
# =====================================
# result of model number :  2  for cv value  2  is  [-0.00156144 -0.11225673]
# -----------------------------------
# result of model number :  2  for cv value  3  is  [-0.00280468 -0.05378954 -0.34698987]
# -----------------------------------
# result of model number :  2  for cv value  4  is  [-0.030924   -0.03658466 -0.01685248 -0.54902257]
# -----------------------------------
# result of model number :  2  for cv value  5  is  [-0.02910078  0.00139346 -0.04981805 -0.13714343 -0.23801791]
# -----------------------------------
# result of model number :  2  for cv value  6  is  [-0.00195566 -0.00949734 -0.01206352 -0.06342245 -0.35718809 -0.25921632]
# -----------------------------------
# result of model number :  2  for cv value  7  is  [ 0.00106911 -0.0139978  -0.02090474  0.00063447 -0.03317158 -0.38033609
#  -0.38021959]
# -----------------------------------
# result of model number :  2  for cv value  8  is  [-0.00952857 -0.04980909 -0.02156903 -0.03547645 -0.11648249 -0.06201932
#  -0.82810473 -0.25877082]
# -----------------------------------
# result of model number :  2  for cv value  9  is  [-0.01790714 -0.01554326 -0.00228999 -0.13383137 -0.00251868 -0.204869
#  -0.42731207 -0.1558204  -0.40473482]
# -----------------------------------
# result of model number :  2  for cv value  10  is  [-4.05824794e-03 -3.60447113e-02 -1.09565531e-02 -2.22216382e-02
#  -1.18666055e-02 -7.79883595e-02  1.01697420e-04 -4.72351685e-01
#  -5.36634747e-02 -4.96197921e-01]
# -----------------------------------
# =====================================
# =====================================
# result of model number :  3  for cv value  2  is  [-0.15388085  0.02883098]
# -----------------------------------
# result of model number :  3  for cv value  3  is  [-0.09875537 -0.97979928 -0.24260876]
# -----------------------------------
# result of model number :  3  for cv value  4  is  [-0.1225579  -0.51868687 -0.72837376  0.09636455]
# -----------------------------------
# result of model number :  3  for cv value  5  is  [-0.80555571  0.06041526 -0.25552284  0.16114625 -0.09059952]
# -----------------------------------
# result of model number :  3  for cv value  6  is  [-0.628207   -0.08865788 -0.75264964 -0.6600976   0.12500528 -0.13218548]
# -----------------------------------
# result of model number :  3  for cv value  7  is  [-1.16011509  0.36392285 -0.89815341 -0.63020142 -0.57206683 -0.7355169
#   0.13086325]
# -----------------------------------
# result of model number :  3  for cv value  8  is  [-1.52807974 -0.01193443 -0.57425663 -0.59038488 -0.51114585  0.09320249
#  -1.67112786  0.12292364]
# -----------------------------------
# result of model number :  3  for cv value  9  is  [-0.16332407  0.159159   -0.32699341 -1.7718655  -0.64063849 -0.19351737
#   0.16700716 -2.02259583 -0.0810474 ]
# -----------------------------------
# result of model number :  3  for cv value  10  is  [-0.47465084 -0.87413028  0.43108668 -1.44025898 -0.87512467  0.09448115
#   0.1027326  -0.12342584 -0.60140551  0.25437107]
# -----------------------------------
# =====================================
# =====================================
# result of model number :  4  for cv value  2  is  [0.39135572 0.39256328]
# -----------------------------------
# result of model number :  4  for cv value  3  is  [0.31703974 0.03699517 0.41806122]
# -----------------------------------
# result of model number :  4  for cv value  4  is  [0.28913491 0.21156815 0.12960495 0.29588385]
# -----------------------------------
# result of model number :  4  for cv value  5  is  [-0.01411026  0.3114318   0.36207472  0.40933063  0.42718065]
# -----------------------------------
# result of model number :  4  for cv value  6  is  [0.15653976 0.48353209 0.19265633 0.06214071 0.29283642 0.54377197]
# -----------------------------------
# result of model number :  4  for cv value  7  is  [-0.13821772  0.53201399  0.07582813  0.24792495 -0.04917093  0.33493226
#   0.46814016]
# -----------------------------------
# result of model number :  4  for cv value  8  is  [-0.00074948  0.36280843 -0.03425176  0.47469767  0.17043455  0.25553756
#   0.24606298  0.57242872]
# -----------------------------------
# result of model number :  4  for cv value  9  is  [ 0.07988009  0.46526829  0.38903797 -0.30179174  0.2165332  -0.04664142
#   0.41027235  0.1485361   0.52636424]
# -----------------------------------
# result of model number :  4  for cv value  10  is  [ 0.07984783  0.18398156  0.46710675 -0.3121025   0.53264712  0.24386098
#   0.09570332  0.64394858  0.0429908   0.50410983]
# -----------------------------------
# =====================================
# =====================================
